# %%
import requests
import bs4
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/MasterChef_Australia_(series_13)"
requests.get(url)
# Out:
# <Response [200]>

# %%
requests.get(url,{}).text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>MasterChef Australia (series 13) - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"6f130c46-87a0-48ec-88df-3820aa1b7748","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"MasterChef_Australia_(series_13)","wgTitle":"MasterChef Australia (series 13)","wgCurRevisionId":1027999065,"wgRevisionId":1027999065,"wgArticleId":67119135,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: dates","Articles with short description","Short description matches Wikidata","Use dmy da
# ...

# %%
web_page= bs4.BeautifulSoup(requests.get(url,{}).text)
web_page
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>MasterChef Australia (series 13) - Wikipedia</title>
# ...

# %%
tables = web_page.find_all(name="tbody")[1]
tables = tables('tr')
tables[1]
# Out:
# <tr>
# <td>Aaron Sanders
# </td>
# <td>34
# </td>
# <td>SA
# </td>
# <td>Insurance claims manager
# </td>
# <td style="background:#87D3F8;">Competing
# </td></tr>

# %%
columns = ["Contestant","Age","State/Terr","Occupation", "Status"]

# %%
temp_list=[]
for table in tables:
    data= table.find_all(name="td")
    temp_list.append([x.text[:-1] for x in data])
# del temp_list[8:10]
print(temp_list)
df = pd.DataFrame(data=temp_list,columns=columns)
df
# Out:
# [[], ['Aaron Sanders', '34', 'SA', 'Insurance claims manager', 'Competing'], ['Brent Draper', '31', 'QLD', 'Boilermaker', 'Competing'], ['Depinder Chhibber', '29', 'NSW', 'Pharmacist', 'Competing'], ['Elise Pulbrook', '28', 'VIC', 'Lawyer', 'Competing'], ['Justin Narayan', '27', 'WA', 'Youth pastor', 'Competing'], ['Kishwar Chowdhury', '38', 'VIC', 'Printing business owner', 'Competing'], ['Linda Dalrymple', '38', 'NSW', 'Stay-at-home mum', 'Competing'], ['Maja Veit', '33', 'WA', 'Small business owner', 'CompetingReturned 3 JuneEliminated 4 May'], ['Minoli De Silva', '34', 'NT', 'Chemical engineer', 'CompetingReturned 1 JuneEliminated 2 May'], ['Pete Campbell', '36', 'NSW', 'Tattoo artist', 'Competing'], ['Sabina Newton', '21', 'TAS', 'Commerce student', 'Competing'], ['Scott Bagnell', '40', 'QLD', 'Commercial interior designer', 'Competing'], ['Tommy Pham', '31', 'NSW', 'Kindergarten teacher', 'Competing'], ['Amir Manoly', '30', 'VIC', 'Construction project manager', 'Eliminated 8 J
# ...

# %%
# table_dict = {columns[idx] : temp_list[idx] for idx,val in enumerate(temp_list) }
# table_list.append(table_dict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-88184c0a7331> in <module>
# ----> 1 table_dict = {columns[idx] : temp_list[idx] for idx,val in enumerate(temp_list) }
#       2 table_list.append(table_dict)
#
# <ipython-input-58-88184c0a7331> in <dictcomp>(.0)
# ----> 1 table_dict = {columns[idx] : temp_list[idx] for idx,val in enumerate(temp_list) }
#       2 table_list.append(table_dict)
#
# IndexError: list index out of range

# %%
# data_arr=[]
# temp=[]
# new_temp=[]
# for table in tables:
#     for idx, data in enumerate(table):
#         data_arr.append(data)
#     for n in data_arr:
#         new_temp.append(data_arr[:5])
#         temp.append(new_temp)
#         del data_arr[:5]
# print(temp)

# %%
# table_list = []
# table_list2 = []
# new_templist = []
# temp_list=[]

# for table in tables:
#     for idx,data in enumerate(table):
#         print(type(data))

# #         for n in range(len(data)):
# #             new_templist.append(data[0:5])
# #             del data[0:5]
            

# #         del table[n]
# #             new_templist.append(data)
# #         temp_list.append(data)
# #         print(data)

# # for n in range(0,5):
# #     new_templist.append(temp_list[n])
# #     table_list2.append(new_templist)
# #     del temp_list[n]



# # print(table_list2)
# # print(temp_list)


# # table_ist = []
# # for table in tables:
# #     temp_list=[]
# #     for idx,data in enumerate(table):
# # #         details = [x.text for x in data]
# #         temp_list.append(data[:-1])
# #     print(temp_list)
